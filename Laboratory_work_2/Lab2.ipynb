# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Laboratory-work-2" data-toc-modified-id="Laboratory-work-2-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Laboratory work 2</a></span><ul class="toc-item"><li><span><a href="#Work-description" data-toc-modified-id="Work-description-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Work description</a></span></li><li><span><a href="#Import-libraries" data-toc-modified-id="Import-libraries-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Import libraries</a></span></li><li><span><a href="#Load-data" data-toc-modified-id="Load-data-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Load data</a></span></li><li><span><a href="#Plot-data" data-toc-modified-id="Plot-data-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Plot data</a></span></li></ul></li><li><span><a href="#Model-with-n=2" data-toc-modified-id="Model-with-n=2-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Model with n=2</a></span><ul class="toc-item"><li><span><a href="#Create-recursive-data" data-toc-modified-id="Create-recursive-data-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Create recursive data</a></span></li><li><span><a href="#Plot-data-in-3D" data-toc-modified-id="Plot-data-in-3D-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Plot data in 3D</a></span></li><li><span><a href="#Create-training-data" data-toc-modified-id="Create-training-data-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Create training data</a></span></li><li><span><a href="#Create-a-linear-regression-using-sklearn" data-toc-modified-id="Create-a-linear-regression-using-sklearn-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Create a linear regression using sklearn</a></span><ul class="toc-item"><li><span><a href="#Train-the-network" data-toc-modified-id="Train-the-network-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Train the network</a></span></li><li><span><a href="#Display-neuron-weight-coefficient-values" data-toc-modified-id="Display-neuron-weight-coefficient-values-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Display neuron weight coefficient values</a></span></li></ul></li><li><span><a href="#Test-the-performance-of-previous-model" data-toc-modified-id="Test-the-performance-of-previous-model-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Test the performance of previous model</a></span><ul class="toc-item"><li><span><a href="#Predict-on-training-data" data-toc-modified-id="Predict-on-training-data-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Predict on training data</a></span></li><li><span><a href="#Display-on-training-data" data-toc-modified-id="Display-on-training-data-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Display on training data</a></span></li><li><span><a href="#Simulate-on-testing-data" data-toc-modified-id="Simulate-on-testing-data-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Simulate on testing data</a></span></li><li><span><a href="#Forecast-error" data-toc-modified-id="Forecast-error-2.5.4"><span class="toc-item-num">2.5.4&nbsp;&nbsp;</span>Forecast error</a></span></li></ul></li><li><span><a href="#Create-a-linear-regression-by-ourselves" data-toc-modified-id="Create-a-linear-regression-by-ourselves-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Create a linear regression by ourselves</a></span><ul class="toc-item"><li><span><a href="#Check-training-data-shapes" data-toc-modified-id="Check-training-data-shapes-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>Check training data shapes</a></span></li><li><span><a href="#Train-the-network-and-display-training" data-toc-modified-id="Train-the-network-and-display-training-2.6.2"><span class="toc-item-num">2.6.2&nbsp;&nbsp;</span>Train the network and display training</a></span></li></ul></li><li><span><a href="#Test-the-performance-of-our-model" data-toc-modified-id="Test-the-performance-of-our-model-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Test the performance of our model</a></span><ul class="toc-item"><li><span><a href="#Forecast-on-training-data" data-toc-modified-id="Forecast-on-training-data-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span>Forecast on training data</a></span></li><li><span><a href="#Forecast-on-testing-data" data-toc-modified-id="Forecast-on-testing-data-2.7.2"><span class="toc-item-num">2.7.2&nbsp;&nbsp;</span>Forecast on testing data</a></span></li><li><span><a href="#Calculate-error-of-our-model" data-toc-modified-id="Calculate-error-of-our-model-2.7.3"><span class="toc-item-num">2.7.3&nbsp;&nbsp;</span>Calculate error of our model</a></span><ul class="toc-item"><li><span><a href="#Plot-error" data-toc-modified-id="Plot-error-2.7.3.1"><span class="toc-item-num">2.7.3.1&nbsp;&nbsp;</span>Plot error</a></span></li><li><span><a href="#Display-weigths" data-toc-modified-id="Display-weigths-2.7.3.2"><span class="toc-item-num">2.7.3.2&nbsp;&nbsp;</span>Display weigths</a></span></li><li><span><a href="#Calculate-network-forecast-error-using-mse-function" data-toc-modified-id="Calculate-network-forecast-error-using-mse-function-2.7.3.3"><span class="toc-item-num">2.7.3.3&nbsp;&nbsp;</span>Calculate network forecast error using mse function</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Make-a-structure-for-n-=-any-given-number" data-toc-modified-id="Make-a-structure-for-n-=-any-given-number-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Make a structure for n = any given number</a></span></li><li><span><a href="#Model-for-n=6" data-toc-modified-id="Model-for-n=6-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Model for n=6</a></span><ul class="toc-item"><li><span><a href="#Create-data" data-toc-modified-id="Create-data-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Create data</a></span></li><li><span><a href="#Make-a-model-with-sklearn" data-toc-modified-id="Make-a-model-with-sklearn-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Make a model with sklearn</a></span><ul class="toc-item"><li><span><a href="#Print-coefficients" data-toc-modified-id="Print-coefficients-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Print coefficients</a></span></li><li><span><a href="#Prediction-on-training-data" data-toc-modified-id="Prediction-on-training-data-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Prediction on training data</a></span></li><li><span><a href="#Forecast-on-unseen-data" data-toc-modified-id="Forecast-on-unseen-data-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Forecast on unseen data</a></span></li><li><span><a href="#Calculate-errors" data-toc-modified-id="Calculate-errors-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Calculate errors</a></span><ul class="toc-item"><li><span><a href="#MSE-and-MAD" data-toc-modified-id="MSE-and-MAD-4.2.4.1"><span class="toc-item-num">4.2.4.1&nbsp;&nbsp;</span>MSE and MAD</a></span></li></ul></li></ul></li><li><span><a href="#Use-our-homemade-model" data-toc-modified-id="Use-our-homemade-model-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Use our homemade model</a></span><ul class="toc-item"><li><span><a href="#Train-network" data-toc-modified-id="Train-network-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Train network</a></span></li><li><span><a href="#Performance-on-trainin-data" data-toc-modified-id="Performance-on-trainin-data-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Performance on trainin data</a></span></li><li><span><a href="#Forecast-on-testing-data" data-toc-modified-id="Forecast-on-testing-data-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Forecast on testing data</a></span></li><li><span><a href="#Calculate-error" data-toc-modified-id="Calculate-error-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Calculate error</a></span><ul class="toc-item"><li><span><a href="#Weights" data-toc-modified-id="Weights-4.3.4.1"><span class="toc-item-num">4.3.4.1&nbsp;&nbsp;</span>Weights</a></span></li><li><span><a href="#MSE-and-MAD" data-toc-modified-id="MSE-and-MAD-4.3.4.2"><span class="toc-item-num">4.3.4.2&nbsp;&nbsp;</span>MSE and MAD</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Model-for-n=11" data-toc-modified-id="Model-for-n=11-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Model for n=11</a></span><ul class="toc-item"><li><span><a href="#Create-data" data-toc-modified-id="Create-data-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Create data</a></span></li><li><span><a href="#Make-a-model-with-sklearn" data-toc-modified-id="Make-a-model-with-sklearn-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Make a model with sklearn</a></span><ul class="toc-item"><li><span><a href="#Print-coefficients" data-toc-modified-id="Print-coefficients-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Print coefficients</a></span></li><li><span><a href="#Prediction-on-training-data" data-toc-modified-id="Prediction-on-training-data-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Prediction on training data</a></span></li><li><span><a href="#Forecast-on-unseen-data" data-toc-modified-id="Forecast-on-unseen-data-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Forecast on unseen data</a></span></li><li><span><a href="#Calculate-errors" data-toc-modified-id="Calculate-errors-5.2.4"><span class="toc-item-num">5.2.4&nbsp;&nbsp;</span>Calculate errors</a></span><ul class="toc-item"><li><span><a href="#MSE-and-MAD" data-toc-modified-id="MSE-and-MAD-5.2.4.1"><span class="toc-item-num">5.2.4.1&nbsp;&nbsp;</span>MSE and MAD</a></span></li></ul></li></ul></li><li><span><a href="#Use-our-homemade-model" data-toc-modified-id="Use-our-homemade-model-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Use our homemade model</a></span><ul class="toc-item"><li><span><a href="#Train-network" data-toc-modified-id="Train-network-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>Train network</a></span></li><li><span><a href="#Performance-on-trainin-data" data-toc-modified-id="Performance-on-trainin-data-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>Performance on trainin data</a></span></li><li><span><a href="#Forecast-on-testing-data" data-toc-modified-id="Forecast-on-testing-data-5.3.3"><span class="toc-item-num">5.3.3&nbsp;&nbsp;</span>Forecast on testing data</a></span></li><li><span><a href="#Calculate-error" data-toc-modified-id="Calculate-error-5.3.4"><span class="toc-item-num">5.3.4&nbsp;&nbsp;</span>Calculate error</a></span><ul class="toc-item"><li><span><a href="#Weights" data-toc-modified-id="Weights-5.3.4.1"><span class="toc-item-num">5.3.4.1&nbsp;&nbsp;</span>Weights</a></span></li><li><span><a href="#MSE-and-MAD" data-toc-modified-id="MSE-and-MAD-5.3.4.2"><span class="toc-item-num">5.3.4.2&nbsp;&nbsp;</span>MSE and MAD</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Laboratory work 2

# %% [markdown]
# ## Work description

# %% [markdown]
# Artificial neural network with an elementary structure will be used during the work. The structure is a neuron
# with linear activation function (purelin(n)=purelin(Wp+b)=Wp+b ). Neuron task is to forecast the k-th value of
# time series a(k) using n previous values a(k-1), a(k-2), ..., a(k-n). Model that is implemented using a premise
# that a dependency between a forecasted value and previous values can be described using a linear function is
# called autoregressive linear model of the n-th order.

# %% [markdown]
# ## Import libraries

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Load data

# %%
df = pd.read_csv("sunspot.txt", sep='	', header=None, names=['Year', 'Nb of plums'])
df.sample(5)
# Out:
#      Year  Nb of plums
# 116  1816           46
# 40   1740           73
# 33   1733            5
# 168  1868           38
# 6    1706           29

# %%
df.dtypes
# Out:
# Year           int64
# Nb of plums    int64
# dtype: object

# %% [markdown]
# ## Plot data

# %%
ax = plt.plot(df['Year'], df['Nb of plums'])
plt.xlabel("Year")
plt.ylabel("Nb of plums")
plt.title("Nb of plums each year")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Nb of plums each year')

# %% [markdown]
# # Model with n=2

# %% [markdown]
# ## Create recursive data

# %% [markdown]
# **5. Let us set the order of autoregressive model will be 2 (n=2). That is, we premise that next year’s
# plum forecast is possible based only on two previous years. Then, a neuron will has only two inputs.
# Supplement the scenario by describing matrices P and T, that contain input (training) data and
# output data correspondingly (see figure 1.1).**

# %%
# Number of lines
L = df.count()[0]

# Training input data
P = np.transpose(np.array([df['Nb of plums'][0:L-2], df['Nb of plums'][1:L-1]]))

# Training output data
T = np.transpose(np.array([df['Nb of plums'][2:L]]))


# Display training data
print("L length: ", L)
print("P size and content:", P.size, P)
print("T size and content:", T.size, T)
# Out:
# L length:  315
# P size and content: 626 [[  5  11]
#  [ 11  16]
#  [ 16  23]
#  [ 23  36]
#  [ 36  58]
#  [ 58  29]
#  [ 29  20]
#  [ 20  10]
#  [ 10   8]
#  [  8   3]
#  [  3   0]
#  [  0   0]
#  [  0   2]
#  [  2  11]
#  [ 11  27]
#  [ 27  47]
#  [ 47  63]
#  [ 63  60]
#  [ 60  39]
#  [ 39  28]
#  [ 28  26]
#  [ 26  22]
#  [ 22  11]
#  [ 11  21]
#  [ 21  40]
#  [ 40  78]
#  [ 78 122]
#  [122 103]
#  [103  73]
#  [ 73  47]
#  [ 47  35]
#  [ 35  11]
#  [ 11   5]
#  [  5  16]
#  [ 16  34]
#  [ 34  70]
#  [ 70  81]
#  [ 81 111]
#  [111 101]
#  [101  73]
#  [ 73  40]
#  [ 40  20]
#  [ 20  16]
#  [ 16   5]
#  [  5  11]
#  [ 11  22]
#  [ 22  40]
#  [ 40  60]
#  [ 60  81]
#  [ 81  83]
#  [ 83  48]
#  [ 48  48]
#  [ 48  31]
#  [ 31  12]
#  [ 12  10]
#  [ 10  10]
#  [ 10  32]
#  [ 32  48]
#  [ 48  54]
#  [ 54  63]
#  [ 63  86]
#  [ 86  61]
#  [ 61  45]
#  [ 45  36]
#  [ 36  21]
#  [ 21  11]
#  [ 11  38]
#  [ 38  70]
#  [ 70 106]
#  [106 101]
#  [101  82]
#  [ 82  67]
#  [ 67  35]
# ...

# %% [markdown]
# ## Plot data in 3D

# %% [markdown]
# **6. Introduce yourself with parameters of functions: plot3, grid, zlabel. Plot a diagram in a new
# graphical window (figure 2) with the following contents – inputs and outputs ( P and T
# correspondingly). Supplement the scenario. E.g. to call plotting function plot3 you may use
# plot3(P(1,:),P(2,:),T,'bo') . Run the scenario, analyze the figure. Add axis and
# figure titles. What is a graphical interpretation of optimal values of neuron weight coefficients w1,
# w2, b ? Note: to rotate a figure you may use Rotate 3D icon.**

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')


# Data for a three-dimensional line
zline = T
xline = P[:,0]
yline = P[:,1]
# ax.plot3D(xline, yline, zline, 'gray')
ax.scatter3D(xline, yline, zline, 'gray')

ax.set_xlabel('k-2')
ax.set_ylabel('k-1')
ax.set_zlabel('k')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0, 'k')

# %% [markdown]
# When we rotate the view, we can find a view where the original dataset almost makes a straight line.
# The optimal weights are the ones related to the angles of this line.

# %% [markdown]
# ## Create training data

# %% [markdown]
# **7. Let us select from inputs P and outputs T data set fragments of 200 members – so called training
# data set. Using that set we will calculate optimal values of neuron weight coefficients (parameters
# of autoregressive model). The rest data will be used for model testing. Then, using existing matrices
# P and T , let us define two new ones – Pu and Tu. For example: definition of a Pu matrix may be as
# follows Pu = P(:,1:200);**

# %%
# Number of members in training data
n_training = 200

# %%
# Input training data
Pu = P[0:n_training,:]

# Output training data
Tu = T[0:n_training,:]

# %% [markdown]
# We check the shapes of data

# %%
Pu.shape
# Out:
# (200, 2)

# %%
Tu.shape
# Out:
# (200, 1)

# %% [markdown]
# ## Create an artifial linear neuron using sklearn

# %% [markdown]
# **8. Create an artificial neuron of the structure that had been discussed before. Calculate its weight
# coefficients using a direct way (function newlind). To do so, use matrices of training data Pu and
# Tu. Name a variable that describes a network by net. Add a corresponding command to the
# scenario.**

# %% [markdown]
# ### Train the network

# %%
net = LinearRegression()
net.fit(Pu, Tu)
# Out:
# LinearRegression()

# %% [markdown]
# **9.Display corresponding neuron weight coefficient values:**
#
# disp(' neuron weight coefficient values:' )
#
# disp( net.IW{1} )
#
# disp( net.b{1} )
#
#
# **Assign corresponding weight coefficient values to auxiliary variables**
#
# w1 = net.IW{1}(1)
#
# w2 = net.IW{1}(2)
#
# b = net.b{1}

# %% [markdown]
# ### Display neuron weight coefficient values

# %%
w1 = net.coef_[0,0]
w2 = net.coef_[0,1]
b = net.intercept_[0]

# %%
print('neuron weight coefficient values:')
print( net.coef_[0])
print( net.intercept_[0])
# Out:
# neuron weight coefficient values:
# [-0.67608198  1.37150939]
# 13.40368323671811

# %% [markdown]
# ## Test the performance of previous model

# %% [markdown]
# **10.** During next step perform a testing of the developed model – i.e. check its forecast quality using
# network simulation. Initially we will do so using training data that was used for calculation of
# weight coefficients.
#
#
# For example, we need to forecast sun plum activity for 1702–1901. For that purpose we supply into
# neuron inputs data sets corresponding the following years: 1700 and 1701, 1701 and 1702, …, 1899
# and 1900. This can be done in a computerized way using input data from matrix Pu. Following this,
# we will obtain resulting vector Tsu, i.e. forecasted sun plum activity values for 1702–1901 :
#
#
# Tsu = sim(net,Pu)
#
# Since we have true values during the analyzed period (Tu), we can compare them with forecasted
# ones (Tsu). To do so we can use several figures on the same graphical window (hold on). The
# resulting window should contain different colors for each diagram and a legend (legend).
#
# Add corresponding commands to the scenario.

# %% [markdown]
# ### Predict on training data

# %%
Tsu = net.predict(Pu)

# %%
Tsu.shape
# Out:
# (200, 1)

# %% [markdown]
# ### Display on training data

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

x = df['Year'][0:n_training]

ax1.plot(x, Tu,'--bo', markersize=2, label='real')
ax1.plot(x, Tsu, "--ro", markersize=2, label='forecasted')
plt.legend(loc='upper left')
plt.title('Real and forecasted sun plums')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Simulate on testing data

# %% [markdown]
# **11. Do the same simulation for the rest of the data. Draw a comparison diagram depicting forecasted
# Ts (neuron outputs) and true values T. Note: you should not recalculate weight coefficients.**

# %%
Ts = net.predict(P[n_training:,])
Ts.shape
# Out:
# (113, 1)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

x = df['Year'][n_training+2:]

ax1.plot(x, Ts,'--bo', markersize=2, label='real')
ax1.plot(x, T[n_training:], "--ro", markersize=2, label='forecasted')
plt.legend(loc='upper left')
plt.title('Real and forecasted sun plums')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Forecast error

# %% [markdown]
# **12. Create forecast error vector e (see expression 1.2). In a new window draw error diagram (plot).**
# Describe axis and chart titles.

# %%
Ts.shape
# Out:
# (113, 1)

# %%
T[n_training:].shape
# Out:
# (113, 1)

# %%
e = Ts - T[n_training:]

# %%
plt.figure()
plt.plot(df['Year'][n_training+2:], e, "-ro", markersize=2, label='forecasted')
plt.legend()
plt.title('forecasted sun plums errors')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **13. Draw forecast error histogram (hist).**

# %%
plt.figure()
plt.hist(e, bins=20, label='forecasted')
plt.legend()
plt.title('forecasted sun plums errors')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# **14. Using (1.3) calculate Mean-Square-Error, MSE and MAD (see explanation in presentation file):**

# %%
MSE = np.mean(e**2)
MAD = np.mean(np.abs(e))

# %%
print("MSE: ", MSE)
print("MAD: ", MAD )
# Out:
# MSE:  386.4041931492969
# MAD:  14.926462705790664

# %% [markdown]
# ## Create a linear regression by ourselves

# %% [markdown]
# **16. Using function newlin (see application illustration: help newlin) create direct neuron. Define
# function parameters (input delay – 0 and learning rate (lr) – between 0 and 1).**

# %%
class AdaptiveLinearNeuron(object):
   def __init__(self, rate = 0.01, niter = 10, goal=100):
      self.rate = rate
      self.niter = niter
      self.goal = goal
   def fit(self, X, y):
      """Fit training data
      X : Training vectors, X.shape : [#samples, #features]
      y : Target values, y.shape : [#samples]
      """

      # weights
      self.weight = np.zeros(1 + X.shape[1])

      # Number of misclassifications
      self.errors = []

      # Cost function
      self.cost = []

      for i in range(self.niter):
         output = self.net_input(X)
         errors = y - output
            
         
         self.weight[1:] += self.rate * X.T.dot(errors)
         self.weight[0] += self.rate * errors.sum()
         cost = np.mean(errors**2)
         self.cost.append(cost)
        
         if (self.cost[i] < self.goal):
            return self
      return self

   def fit2(self, X, y, Xt,yt):
      """Fit training data
      X : Training vectors, X.shape : [#samples, #features]
      y : Target values, y.shape : [#samples]
      """

      # weights
      self.weight = np.zeros(1 + X.shape[1])

      # Number of misclassifications
      self.errors = []

      # Cost function
      self.cost = []
        
      self.MSE_Test = []
    
      for i in range(self.niter):
         output = self.net_input(X)
         errors = y - output
        
         self.weight[1:] += self.rate * X.T.dot(errors)
         self.weight[0] += self.rate * errors.sum()
        
         cost = np.mean(errors**2)
         self.cost.append(cost)
        
         MSE_Test = np.mean((yt - self.net_input(Xt).reshape(Xt[:,1].size,1))**2)
         self.MSE_Test.append(MSE_Test)
        
         if (self.cost[i] < self.goal):
            return self
      return self

   def net_input(self, X):
      """Calculate net input"""
      return np.dot(X, self.weight[1:]) + self.weight[0]

   def activation(self, X):
      """Compute linear activation"""
      return self.net_input(X)

   def predict(self, X):
      """Return class label after unit step"""
      return np.where(self.activation(X) >= 0.0, 1, -1)

# %% [markdown]
# ### Check training data shapes

# %%
Tu[:,0].shape
# Out:
# (200,)

# %%
Pu.shape
# Out:
# (200, 2)

# %% [markdown]
# ### Train the network and display training

# %%
# Training data
X = Pu      # Training data input
y = Tu[:,0] # Training data output

# Parameters
epochs = 5000
goal = 100
learning_rate = 0.00000164


# Train
aln2 = AdaptiveLinearNeuron(learning_rate, epochs, goal).fit(X,y)

# Plot result
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(range(1, len(aln2.cost) + 1), aln2.cost, marker='o')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Mean-squared-error')
ax1.set_title('Adaptive Linear Neuron - Learning rate {}'.format(learning_rate))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Test the performance of our model

# %% [markdown]
# ### Forecast on training data

# %%
TsT = aln2.net_input(P[0:n_training,]).reshape(P[0:n_training,1].size,1)

# %%
TsT.shape
# Out:
# (200, 1)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

x = df['Year'][:n_training]

ax1.plot(x, T[:n_training],'--bo', markersize=2, label='real')
ax1.plot(x, TsT, "--ro", markersize=2, label='forecasted')
plt.legend(loc='upper left')
plt.title('Real and forecasted sun plums')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Forecast on testing data

# %%
# reshape is necessary to have the right shape
Ts2 = aln2.net_input(P[n_training:,]).reshape((P[n_training:,1].size,1))

# %%
Ts2.shape
# Out:
# (113, 1)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

x = df['Year'][n_training+2:]

ax1.plot(x, T[n_training:],'--bo', markersize=2, label='real')
ax1.plot(x, Ts2, "--ro", markersize=2, label='forecasted')
plt.legend(loc='upper left')
plt.title('Real and forecasted sun plums')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Calculate error of our model

# %% [markdown]
# #### Plot error

# %%
e2 = Ts2 - T[n_training:]

# %%
plt.figure()
plt.plot(df['Year'][n_training+2:], e2, "-ro", markersize=2, label='forecasted')
plt.legend()
plt.title('forecasted sun plums errors')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Display weigths

# %%
print("weights: ", aln2.weight)
# Out:
# weights:  [ 5.96745981 -0.62252244  1.42582436]

# %% [markdown]
# #### Calculate network forecast error using mse function

# %%
MSE2 = np.mean(e2**2)
print("MSE:",MSE2)
# Out:
# MSE: 426.10936747778777

# %% [markdown]
# **Calculate network forecast error using mad function**

# %%
MAD2 = np.median(np.abs(e2))
print("MAD:", MAD2)
# Out:
# MAD: 11.846376821998906

# %% [markdown]
# # Make a structure for n = any given number

# %%
def createData(df, n=1):
    P = np.array([df['Nb of plums'][0:L-n],])
    for i in range(1,n):
        P = np.append(P, [df['Nb of plums'][i:L-n+i]], axis=0)
    P = np.transpose(P)
    T = np.transpose(np.array([df['Nb of plums'][n:L]]))
    return [P,T]


def createTrainingData(P,T, nb):
    return [P[0:nb,], T[0:nb]]

# %% [markdown]
# # Model for n=6

# %% [markdown]
# ## Create data

# %%
P6, T6 = createData(df, n=6)

# %%
print("Input data:\n", P6)
print("Output data:\n", T6)
# Out:
# Input data:
#  [[ 5 11 16 23 36 58]
#  [11 16 23 36 58 29]
#  [16 23 36 58 29 20]
#  ...
#  [15  7  3  4 16 57]
#  [ 7  3  4 16 57 58]
#  [ 3  4 16 57 58 65]]
# Output data:
#  [[ 29]
#  [ 20]
#  [ 10]
#  [  8]
#  [  3]
#  [  0]
#  [  0]
#  [  2]
#  [ 11]
#  [ 27]
#  [ 47]
#  [ 63]
#  [ 60]
#  [ 39]
#  [ 28]
#  [ 26]
#  [ 22]
#  [ 11]
#  [ 21]
#  [ 40]
#  [ 78]
#  [122]
#  [103]
#  [ 73]
#  [ 47]
#  [ 35]
#  [ 11]
#  [  5]
#  [ 16]
#  [ 34]
#  [ 70]
#  [ 81]
#  [111]
#  [101]
#  [ 73]
#  [ 40]
#  [ 20]
#  [ 16]
#  [  5]
#  [ 11]
#  [ 22]
#  [ 40]
#  [ 60]
#  [ 81]
#  [ 83]
#  [ 48]
#  [ 48]
#  [ 31]
#  [ 12]
#  [ 10]
#  [ 10]
#  [ 32]
#  [ 48]
#  [ 54]
#  [ 63]
#  [ 86]
#  [ 61]
#  [ 45]
#  [ 36]
#  [ 21]
#  [ 11]
#  [ 38]
#  [ 70]
#  [106]
#  [101]
#  [ 82]
#  [ 67]
#  [ 35]
#  [ 31]
#  [  7]
#  [ 20]
#  [ 93]
#  [154]
#  [126]
#  [ 85]
#  [ 68]
#  [ 39]
#  [ 23]
#  [ 10]
#  [ 24]
#  [ 83]
#  [132]
#  [131]
#  [118]
#  [ 90]
#  [ 67]
#  [ 60]
#  [ 47]
#  [ 41]
#  [ 21]
#  [ 16]
# ...

# %%
# Set number of members for training
n_training6 = 166

# %%
P6Training, T6Training = createTrainingData(P6, T6, n_training6)

# %%
print("Training input:\n", P6Training)
print("Training output:\n", T6Training)
# Out:
# Training input:
#  [[  5  11  16  23  36  58]
#  [ 11  16  23  36  58  29]
#  [ 16  23  36  58  29  20]
#  [ 23  36  58  29  20  10]
#  [ 36  58  29  20  10   8]
#  [ 58  29  20  10   8   3]
#  [ 29  20  10   8   3   0]
#  [ 20  10   8   3   0   0]
#  [ 10   8   3   0   0   2]
#  [  8   3   0   0   2  11]
#  [  3   0   0   2  11  27]
#  [  0   0   2  11  27  47]
#  [  0   2  11  27  47  63]
#  [  2  11  27  47  63  60]
#  [ 11  27  47  63  60  39]
#  [ 27  47  63  60  39  28]
#  [ 47  63  60  39  28  26]
#  [ 63  60  39  28  26  22]
#  [ 60  39  28  26  22  11]
#  [ 39  28  26  22  11  21]
#  [ 28  26  22  11  21  40]
#  [ 26  22  11  21  40  78]
#  [ 22  11  21  40  78 122]
#  [ 11  21  40  78 122 103]
#  [ 21  40  78 122 103  73]
#  [ 40  78 122 103  73  47]
#  [ 78 122 103  73  47  35]
#  [122 103  73  47  35  11]
#  [103  73  47  35  11   5]
#  [ 73  47  35  11   5  16]
#  [ 47  35  11   5  16  34]
#  [ 35  11   5  16  34  70]
#  [ 11   5  16  34  70  81]
# ...

# %% [markdown]
# ## Make a model with sklearn

# %%
net6 = LinearRegression()
net6.fit(P6Training, T6Training)
# Out:
# LinearRegression()

# %% [markdown]
# ### Print coefficients

# %%
w1 = net6.coef_[0,0]
w2 = net6.coef_[0,1]
w3 = net6.coef_[0,2]
w4 = net6.coef_[0,3]
w5 = net6.coef_[0,4]
w6 = net6.coef_[0,5]

b = net6.intercept_[0]

# %%
print('neuron weight coefficient values:')
print(net6.coef_[0])
print(net6.intercept_[0])
# Out:
# neuron weight coefficient values:
# [ 0.14423002 -0.18406618  0.04805035  0.07886574 -0.74576277  1.3864663 ]
# 12.318389719830407

# %% [markdown]
# ### Prediction on training data

# %%
Tsu6 = net6.predict(P6Training)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

x = df['Year'][0:n_training6]

ax1.plot(x, T6Training,'--bo', markersize=2, label='real')
ax1.plot(x, Tsu6, "--ro", markersize=2, label='forecasted')
plt.legend(loc='upper left')
plt.title('Real and forecasted sun plums')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Forecast on unseen data

# %%
Ts6 = net6.predict(P6[n_training6:,])

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

x = df['Year'][n_training6+6:]

ax1.plot(x, Ts6,'--bo', markersize=2, label='real')
ax1.plot(x, T6[n_training6:], "--ro", markersize=2, label='forecasted')
plt.legend(loc='upper left')
plt.title('Real and forecasted sun plums')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Calculate errors

# %%
e6 = Ts6 - T6[n_training6:]

# %%
plt.figure()
plt.plot(df['Year'][n_training6+6:], e6, "-ro", markersize=2, label='forecasted')
plt.legend()
plt.title('forecasted sun plums')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.hist(e6, bins=20, label='forecasted')
plt.legend()
plt.title('forecasted sun plums')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### MSE and MAD

# %%
MSE = np.mean(e6**2)
MAD = np.median(np.abs(e6))
print("MSE:", MSE)
print("MAD:", MAD)
# Out:
# MSE: 326.6203554765681
# MAD: 9.949697662446113

# %% [markdown]
# ## Use our homemade model

# %% [markdown]
# ### Train network

# %%
# Training data
X6 = P6Training     # Training data input
y6 = T6Training[:,0] # Training data output

# Test data
X6t = P6[n_training6:,:]
y6t = T6[n_training6:]

# Parameters
epochs6 = 200
goal6 = 100
learning_rate6 = 0.0000005


# Train
aln6 = AdaptiveLinearNeuron(learning_rate6, epochs6, goal6).fit2(X6,y6,X6t,y6t)

# Plot result
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(range(1, len(aln6.cost) + 1), np.log10(aln6.cost), marker='o', label='Training')
ax1.plot(range(1, len(aln6.cost) + 1), np.log10(aln6.MSE_Test), marker='o', label='Testing')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('log10(Mean-squared-error)')
ax1.set_title('Adaptive Linear Neuron - Learning rate {}'.format(learning_rate6))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Performance on trainin data

# %%
TsT6 = aln6.net_input(P6[0:n_training6,]).reshape(P6[0:n_training6,1].size,1)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

x = df['Year'][:n_training6]

ax1.plot(x, T6[:n_training6],'--bo', markersize=2, label='real')
ax1.plot(x, TsT6, "--ro", markersize=2, label='forecasted')
plt.legend(loc='upper left')
plt.title('Real and forecasted sun plums')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
e6_1 = TsT6 - T6[:n_training6]

# %%
MSE6_1 = np.mean(e6_1**2)
MAD6_1 = np.median(np.abs(e6_1))
print("MSE:", MSE6_1)
print("MAD:", MAD6_1)
# Out:
# MSE: 269.5481553494979
# MAD: 9.042907620057724

# %% [markdown]
# ### Forecast on testing data

# %%
Ts6 = aln6.net_input(P6[n_training6:,]).reshape((P6[n_training6:,1].size,1))

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

x = df['Year'][n_training6+6:]

ax1.plot(x, T6[n_training6:],'--bo', markersize=2, label='real')
ax1.plot(x, Ts6, "--ro", markersize=2, label='forecasted')
plt.legend(loc='upper left')
plt.title('Real and forecasted sun plums')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Calculate error

# %%
e6_2 = Ts6 - T6[n_training6:]

# %%
plt.figure()
plt.plot(df['Year'][n_training6+6:], e6_2, "-ro", markersize=2, label='forecasted')
plt.legend()
plt.title('forecasted sun plums')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.hist(e6, bins=20, label='forecasted')
plt.legend()
plt.title('forecasted sun plums')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Weights

# %%
print("weights: ", aln6.weight)
# Out:
# weights:  [ 0.04946543  0.22109538 -0.10328794  0.06947721 -0.16693326 -0.3874001
#   1.31956365]

# %% [markdown]
# #### MSE and MAD

# %%
MSE6_2 = np.mean(e6_2**2)
MAD6_2 = np.median(np.abs(e6_2))
print("MSE:", MSE6_2)
print("MAD:", MAD6_2)
# Out:
# MSE: 335.877092391017
# MAD: 10.992599362358359

# %% [markdown]
# # Model for n=11

# %% [markdown]
# ## Create data

# %%
P11, T11 = createData(df, n=11)

# %%
print("Input data:\n", P11)
print("Output data:\n", T11)
# Out:
# Input data:
#  [[  5  11  16 ...  10   8   3]
#  [ 11  16  23 ...   8   3   0]
#  [ 16  23  36 ...   3   0   0]
#  ...
#  [111 104  64 ...   4  16  57]
#  [104  64  40 ...  16  57  58]
#  [ 64  40  30 ...  57  58  65]]
# Output data:
#  [[  0]
#  [  0]
#  [  2]
#  [ 11]
#  [ 27]
#  [ 47]
#  [ 63]
#  [ 60]
#  [ 39]
#  [ 28]
#  [ 26]
#  [ 22]
#  [ 11]
#  [ 21]
#  [ 40]
#  [ 78]
#  [122]
#  [103]
#  [ 73]
#  [ 47]
#  [ 35]
#  [ 11]
#  [  5]
#  [ 16]
#  [ 34]
#  [ 70]
#  [ 81]
#  [111]
#  [101]
#  [ 73]
#  [ 40]
#  [ 20]
#  [ 16]
#  [  5]
#  [ 11]
#  [ 22]
#  [ 40]
#  [ 60]
#  [ 81]
#  [ 83]
#  [ 48]
#  [ 48]
#  [ 31]
#  [ 12]
#  [ 10]
#  [ 10]
#  [ 32]
#  [ 48]
#  [ 54]
#  [ 63]
#  [ 86]
#  [ 61]
#  [ 45]
#  [ 36]
#  [ 21]
#  [ 11]
#  [ 38]
#  [ 70]
#  [106]
#  [101]
#  [ 82]
#  [ 67]
#  [ 35]
#  [ 31]
#  [  7]
#  [ 20]
#  [ 93]
#  [154]
#  [126]
#  [ 85]
#  [ 68]
#  [ 39]
#  [ 23]
#  [ 10]
#  [ 24]
#  [ 83]
#  [132]
#  [131]
#  [118]
#  [ 90]
#  [ 67]
#  [ 60]
#  [ 47]
#  [ 41]
# ...

# %%
# Set number of members for training
n_training11 = 165

# %%
P11Training, T11Training = createTrainingData(P11, T11, n_training11)

# %%
print("Training input:\n", P11Training)
print("Training output:\n", T11Training)
# Out:
# Training input:
#  [[  5  11  16 ...  10   8   3]
#  [ 11  16  23 ...   8   3   0]
#  [ 16  23  36 ...   3   0   0]
#  ...
#  [ 59  44  47 ... 139 111 102]
#  [ 44  47  31 ... 111 102  66]
#  [ 47  31  16 ... 102  66  45]]
# Training output:
#  [[  0]
#  [  0]
#  [  2]
#  [ 11]
#  [ 27]
#  [ 47]
#  [ 63]
#  [ 60]
#  [ 39]
#  [ 28]
#  [ 26]
#  [ 22]
#  [ 11]
#  [ 21]
#  [ 40]
#  [ 78]
#  [122]
#  [103]
#  [ 73]
#  [ 47]
#  [ 35]
#  [ 11]
#  [  5]
#  [ 16]
#  [ 34]
#  [ 70]
#  [ 81]
#  [111]
#  [101]
#  [ 73]
#  [ 40]
#  [ 20]
#  [ 16]
#  [  5]
#  [ 11]
#  [ 22]
#  [ 40]
#  [ 60]
#  [ 81]
#  [ 83]
#  [ 48]
#  [ 48]
#  [ 31]
#  [ 12]
#  [ 10]
#  [ 10]
#  [ 32]
#  [ 48]
#  [ 54]
#  [ 63]
#  [ 86]
#  [ 61]
#  [ 45]
#  [ 36]
#  [ 21]
#  [ 11]
#  [ 38]
#  [ 70]
#  [106]
#  [101]
#  [ 82]
#  [ 67]
#  [ 35]
#  [ 31]
#  [  7]
#  [ 20]
#  [ 93]
#  [154]
#  [126]
#  [ 85]
#  [ 68]
#  [ 39]
#  [ 23]
#  [ 10]
#  [ 24]
#  [ 83]
#  [132]
#  [131]
#  [118]
#  [ 90]
#  [ 67]
#  [ 60]
#  [ 47]
# ...

# %% [markdown]
# ## Make a model with sklearn

# %%
net11 = LinearRegression()
net11.fit(P11Training, T11Training)
# Out:
# LinearRegression()

# %% [markdown]
# ### Print coefficients

# %%
print('neuron weight coefficient values:')
print(net11.coef_[0])
print(net11.intercept_[0])
# Out:
# neuron weight coefficient values:
# [ 0.14128313 -0.19434221  0.197963    0.10948425 -0.10160146  0.08055201
#  -0.1322373   0.12827144 -0.05229405 -0.59586441  1.26661918]
# 7.540719466289737

# %% [markdown]
# ### Prediction on training data

# %%
Tsu11 = net11.predict(P11Training)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

x = df['Year'][0:n_training11]

ax1.plot(x, T11Training,'--bo', markersize=2, label='real')
ax1.plot(x, Tsu11, "--ro", markersize=2, label='forecasted')
plt.legend(loc='upper left')
plt.title('Real and forecasted sun plums')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Forecast on unseen data

# %%
Ts11 = net11.predict(P11[n_training11:,])

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

x = df['Year'][n_training11+11:]

ax1.plot(x, Ts11,'--bo', markersize=2, label='real')
ax1.plot(x, T11[n_training11:], "--ro", markersize=2, label='forecasted')
plt.legend(loc='upper left')
plt.title('Real and forecasted sun plums')
plt.show()
# Out:
# /tmp/ipykernel_5581/116011656.py:1: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure()
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Calculate errors

# %%
e11 = Ts11 - T11[n_training11:]

# %%
plt.figure()
plt.plot(df['Year'][n_training11+11:], e11, "-ro", markersize=2,label='forecasted')
plt.legend()
plt.title('forecasted sun plums')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.hist(e11, bins=20, label='forecasted')
plt.legend()
plt.title('forecasted sun plums')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### MSE and MAD

# %%
MSE = np.mean(e11**2)
MAD = np.mean(np.abs(e11))
print("MSE:", MSE)
print("MAD:", MAD)
# Out:
# MSE: 272.10519848928305
# MAD: 12.5860865934873

# %% [markdown]
# ## Use our homemade model

# %% [markdown]
# ### Train network

# %%
# Training data
X11 = P11Training     # Training data input
y11 = T11Training[:,0] # Training data output

# Test data
X11t = P11[n_training11:,:]
y11t = T11[n_training11:]

# Parameters
epochs11 = 175
goal11 = 100
learning_rate11 = 0.0000004


# Train
aln11 = AdaptiveLinearNeuron(learning_rate11, epochs11, goal11).fit2(X11,y11, X11t,y11t)

# Plot result
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot(range(1, len(aln11.cost) + 1), np.log10(aln11.cost), marker='o', label='Training')
ax1.plot(range(1, len(aln11.cost) + 1), np.log10(aln11.MSE_Test), marker='o', label='Testing')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('log10(Mean-squared-error)')
ax1.set_title('Adaptive Linear Neuron - Learning rate {}'.format(learning_rate11))
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Performance on trainin data

# %%
TsT11 = aln11.net_input(P11[0:n_training11,]).reshape(P11[0:n_training11,1].size,1)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

x = df['Year'][:n_training11]

ax1.plot(x, T11[:n_training11],'--bo', markersize=2, label='real')
ax1.plot(x, TsT11, "--ro", markersize=2, label='forecasted')
plt.legend(loc='upper left')
plt.title('Real and forecasted sun plums')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
e11_1 = TsT11 - T11[:n_training11]

# %%
MSE11_1 = np.mean(e11_1**2)
MAD11_1 = np.median(np.abs(e11_1))
print("MSE:", MSE11_1)
print("MAD:", MAD11_1)
# Out:
# MSE: 228.11904550503002
# MAD: 8.530756735636995

# %% [markdown]
# ### Forecast on testing data

# %%
Ts11 = aln11.net_input(P11[n_training11:,]).reshape((P11[n_training11:,1].size,1))

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111)

x = df['Year'][n_training11+11:]

ax1.plot(x, T11[n_training11:],'--bo', markersize=2, label='real')
ax1.plot(x, Ts11, "--ro", markersize=2, label='forecasted')
plt.legend(loc='upper left')
plt.title('Real and forecasted sun plums')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Calculate error

# %%
e11_2 = Ts11 - T11[n_training11:]

# %%
plt.figure()
plt.plot(df['Year'][n_training11+11:], e11_2, "-ro", markersize=2, label='forecasted')
plt.legend()
plt.title('forecasted sun plums')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Weights

# %%
print("weights: ", aln11.weight)
# Out:
# weights:  [ 0.01631214  0.07151318 -0.0249109   0.14046997  0.10292559 -0.02100729
#   0.00375525  0.03147153  0.04715829 -0.21645001 -0.20692099  1.06278238]

# %% [markdown]
# #### MSE and MAD

# %%
MSE11_2 = np.mean(e11_2**2)
MAD11_2 = np.median(np.abs(e11_2))
print("MSE:", MSE11_2)
print("MAD:", MAD11_2)
# Out:
# MSE: 254.11063630759892
# MAD: 9.433846689933716
